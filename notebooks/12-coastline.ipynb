# %%
import geopandas
import us

# %%
states_cont = [s.abbr for s in us.states.STATES_CONTIGUOUS]

# %%
states = geopandas.read_file('../data/cb_2017_us_state_5m/cb_2017_us_state_5m.shp')

# %%
coast = geopandas.read_file('../data/tl_2017_us_coastline/tl_2017_us_coastline.shp')

# %%
ax = states[states.STUSPS.isin(states_cont)].plot(color='white', edgecolor='white', figsize=(20,20))
coast.plot(ax=ax, edgecolor='black', figsize=(20,20))

# %%
coast.plot(color='white', edgecolor='black', figsize=(20,20))

# %%
coast.iloc[9].geometry

# %%
coast
# Out:
#              NAME  MTFCC                                           geometry
# 0            Gulf  L4150  LINESTRING (-90.35098899999998 29.197628999999...
# 1            Gulf  L4150  LINESTRING (-90.34562499999998 29.146657999999...
# 2            Gulf  L4150  LINESTRING (-90.349313 29.050051, -90.34879199...
# 3            Gulf  L4150  LINESTRING (-90.372354 29.228255, -90.37290199...
# 4            Gulf  L4150  LINESTRING (-90.30022599999998 29.228835, -90....
# 5            Gulf  L4150  LINESTRING (-90.313073 29.23422, -90.312342 29...
# 6            Gulf  L4150  LINESTRING (-90.31286199999998 29.236913, -90....
# 7            Gulf  L4150  LINESTRING (-90.38461599999998 29.143336, -90....
# 8            Gulf  L4150  LINESTRING (-90.32537399999998 29.245374999999...
# 9         Pacific  L4150  LINESTRING (-169.482859 -14.21638399999999, -1...
# 10        Pacific  L4150  LINESTRING (-169.684569 -14.17103099999999, -1...
# ...
